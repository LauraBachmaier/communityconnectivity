# %%
import community_connectivity
# Out:
# Welcome to the Community Connectivity Package!
# This package facilitates multi-species dispersal models using Ocean Parcels and NEMO hydrodynamic data.
# It allows you to setup, run and analyse connectivity data for any marine species and region of your choice.
# See the User Manual XXX for more information and guidance.
# You can use the package in three different ways:
# 1. Interactive: Guided setup of the entire process. Recommended for first time users.
# 2. Automatic: Run the entire process automatically using initial setup parameters.
# 3. Manual: Access individual functions to create a custom workflow.
#
# Please select an option (1, 2, or 3):
# Enter your choice (1 for Interactive, 2 for Automatic, 3 for Manual):  1
# Loading interactive mode...

# %%
from community_connectivity.interactive_functions import *

# %%
load_modules()

# %%
hydrodynamic_parameters = params()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 hydrodynamic_parameters = params()
#
# NameError: name 'params' is not defined

# %%
hydrodata = download_hydrodynamic_data(**hydrodynamic_parameters)
# Out:
# Fetching catalog: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:13<00:00,  4.43s/it]

# %%
fieldset = create_fieldset(hydrodata)
# Out:
# Calculated chunk sizes: {'time': 175, 'lat': 2, 'lon': 7, 'depth': 1}
